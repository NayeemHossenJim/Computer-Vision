# %%
! yolo benchmark model = "C:/Computer-Vision/Ultralytics/1.Model Test/yolo12n.pt" data = "C:/Computer-Vision/OpenCV/0.Data/Cow.mp4" imgsz = 640 half = false
# Out:
# ERROR Benchmark failure for PyTorch: Dataset 'C:/Computer-Vision/OpenCV/0.Data/Cow.mp4' for task=detect not found
#  ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
#
# PyTorch: starting from 'C:\Computer-Vision\Ultralytics\1.Model Test\yolo12n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.3 MB)
#
# TorchScript: starting export with torch 2.9.0+cpu...
# TorchScript: export success  2.1s, saved as 'C:\Computer-Vision\Ultralytics\1.Model Test\yolo12n.torchscript' (10.6 MB)
#
# Export complete (2.3s)
# Results saved to C:\Computer-Vision\Ultralytics\1.Model Test
# Predict:         yolo predict task=detect model=C:\Computer-Vision\Ultralytics\1.Model Test\yolo12n.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Computer-Vision\Ultralytics\1.Model Test\yolo12n.torchscript imgsz=640 data=None
# Visualize:       https://netron.app
# ...
